# %%
import pandas as pd
import numpy as np

import pytz
import astral as ast
from astral import LocationInfo
from astral.sun import sun
from datetime import datetime, timedelta, date

# %%
# read in with pandas
winter1 = pd.read_csv ('ith20-21data.txt')
winter2 = pd.read_csv ('ith21-22data.txt')
winter3 = pd.read_csv ('ith22-23data.txt')

# %%
# rename columns
winter1 = winter1.rename(columns = {'valid': 'datetime', 'p01m': 'precip(mm)'})
winter2 = winter2.rename(columns = {'valid': 'datetime', 'p01m': 'precip(mm)'})
winter3 = winter3.rename(columns = {'valid': 'datetime', 'p01m': 'precip(mm)'})

# datetime format
winter1['datetime'] = pd.to_datetime(winter1['datetime'])
winter2['datetime'] = pd.to_datetime(winter2['datetime'])
winter3['datetime'] = pd.to_datetime(winter3['datetime'])

# %%
# mask out days without precipitation
codes = ['GR','GS','IC','PL','PY','RA','SG','SH','SN','SQ','TS','UP']

mask1 = winter1['wxcodes'].apply(lambda x: any(sub in x for sub in codes))
mask2 = winter2['wxcodes'].apply(lambda x: any(sub in x for sub in codes))
mask3 = winter3['wxcodes'].apply(lambda x: any(sub in x for sub in codes))

precip_days1 = winter1[mask1]
precip_days2 = winter2[mask2]
precip_days3 = winter3[mask3]

# %%
precip_days2
# Out:
#      station            datetime precip(mm) wxcodes
# 0        ITH 2021-12-01 00:56:00          T     -RA
# 2        ITH 2021-12-01 02:56:00          T     -RA
# 3        ITH 2021-12-01 03:13:00          T      UP
# 31       ITH 2021-12-02 03:56:00          T     -RA
# 32       ITH 2021-12-02 04:56:00          T     -RA
# ...      ...                 ...        ...     ...
# 2870     ITH 2022-02-27 22:17:00          T  -SN BR
# 2871     ITH 2022-02-27 22:37:00          T   SN BR
# 2872     ITH 2022-02-27 22:56:00          T  -SN BR
# 2873     ITH 2022-02-27 23:30:00          T     -SN
# 2874     ITH 2022-02-27 23:56:00          T  -SN BR
#
# [1143 rows x 4 columns]

# %%
# replace Trace with 0.0001
precip_days1['precip(mm)'] = precip_days1['precip(mm)'].replace('T', 0.0001)
precip_days2['precip(mm)'] = precip_days2['precip(mm)'].replace('T', 0.0001)
precip_days3['precip(mm)'] = precip_days3['precip(mm)'].replace('T', 0.0001)
# Out:
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\3060002225.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precip_days1['precip(mm)'] = precip_days1['precip(mm)'].replace('T', 0.0001)
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\3060002225.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precip_days2['precip(mm)'] = precip_days2['precip(mm)'].replace('T', 0.0001)
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\3060002225.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precip_days3['precip(mm)'] = precip_days3['precip(mm)'].replace('T', 0.0001)

# %%
precip_days3[430:440]
# Out:
#      station            datetime precip(mm) wxcodes
# 1392     ITH 2023-01-13 15:56:00     0.0001  -SN BR
# 1393     ITH 2023-01-13 16:56:00     0.0001  -SN BR
# 1394     ITH 2023-01-13 17:54:00     0.0001  -SN BR
# 1395     ITH 2023-01-13 17:56:00     0.0001  -SN BR
# 1396     ITH 2023-01-13 18:56:00     0.0001  -SN BR
# 1397     ITH 2023-01-13 19:56:00     0.0001  -SN BR
# 1398     ITH 2023-01-13 20:56:00     0.0001  -SN BR
# 1399     ITH 2023-01-13 21:56:00     0.0001  -SN BR
# 1400     ITH 2023-01-13 22:56:00     0.0001  -SN BR
# 1401     ITH 2023-01-13 23:56:00     0.0001   -FZRA

# %%
# make sure numeric form
precip_days1['precip(mm)'] = pd.to_numeric(precip_days1['precip(mm)'])
precip_days2['precip(mm)'] = pd.to_numeric(precip_days2['precip(mm)'])
precip_days3['precip(mm)'] = pd.to_numeric(precip_days3['precip(mm)'])
# Out:
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\2630444437.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precip_days1['precip(mm)'] = pd.to_numeric(precip_days1['precip(mm)'])
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\2630444437.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precip_days2['precip(mm)'] = pd.to_numeric(precip_days2['precip(mm)'])
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\2630444437.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precip_days3['precip(mm)'] = pd.to_numeric(precip_days3['precip(mm)'])

# %%
# eliminate special weather 
precip_days1 = precip_days1[precip_days1['datetime'].dt.minute == 56]
precip_days2 = precip_days2[precip_days2['datetime'].dt.minute == 56]
precip_days3 = precip_days3[precip_days3['datetime'].dt.minute == 56]

# %%
precip_days1.dtypes
# Out:
# station               object
# datetime      datetime64[ns]
# precip(mm)           float64
# wxcodes               object
# dtype: object

# %%
precip_days1['date'] = precip_days1['datetime'].dt.date

# %%
ith = LocationInfo(
    'Ithica' 'New York', 
    latitude= 42.4440,
    longitude= -76.5019, 
    timezone='America/New_York'
)

ith
# Out:
# LocationInfo(name='IthicaNew York', region='England', timezone='America/New_York', latitude=42.444, longitude=-76.5019)

# %%
# create a date range (winter 1)
date_range1 = pd.date_range(start='2020-12-01', end='2021-2-28', tz='America/New_York')

# lists to store sunrise and sunset times
sunrise_times1 = []
sunset_times1 = []

# Calculate sunrise and sunset for each date
for date in date_range1:
    s = sun(ith.observer, date=date)
    
    sunrise_times1.append(s['sunrise'])
    sunset_times1.append(s['sunset'])

# df with results
sun_times1 = pd.DataFrame({
    'datetime': date_range1.date,
    'sunrise': sunrise_times1,
    'sunset': sunset_times1
})

sun_times1['sunrise'] = pd.to_datetime(sun_times1['sunrise'])
sun_times1['sunset'] = pd.to_datetime(sun_times1['sunset'])

# %%
# create a date range (winter 2)
date_range2 = pd.date_range(start='2021-12-01', end='2022-2-28', tz='America/New_York')

# lists to store sunrise and sunset times
sunrise_times2 = []
sunset_times2 = []

# Calculate sunrise and sunset for each date
for date in date_range2:
    s = sun(ith.observer, date=date)
    
    sunrise_times2.append(s['sunrise'])
    sunset_times2.append(s['sunset'])

# df with results
sun_times2 = pd.DataFrame({
    'datetime': date_range2.date,
    'sunrise': sunrise_times2,
    'sunset': sunset_times2
})

sun_times2['sunrise'] = pd.to_datetime(sun_times2['sunrise'])
sun_times2['sunset'] = pd.to_datetime(sun_times2['sunset'])

# %%
# create a date range (winter 3)
date_range3 = pd.date_range(start='2022-12-01', end='2023-2-28', tz='America/New_York')

# lists to store sunrise and sunset times
sunrise_times3 = []
sunset_times3 = []

# Calculate sunrise and sunset for each date
for date in date_range3:
    s = sun(ith.observer, date=date)
    
    sunrise_times3.append(s['sunrise'])
    sunset_times3.append(s['sunset'])

# df with results
sun_times3 = pd.DataFrame({
    'datetime': date_range3.date,
    'sunrise': sunrise_times3,
    'sunset': sunset_times3
})

sun_times3['sunrise'] = pd.to_datetime(sun_times3['sunrise'])
sun_times3['sunset'] = pd.to_datetime(sun_times3['sunset'])

# %%
# add sunrise and sunset times (winter1)
sun_times1['sunrise'] = sun_times1['sunrise'].dt.strftime('%Y-%m-%d %H:%M:%S')
sun_times1['sunset'] = sun_times1['sunset'].dt.strftime('%Y-%m-%d %H:%M:%S')

sun_times1['date'] = sun_times1['datetime']
sun_times1 = sun_times1.drop(columns=['datetime'])

print(sun_times1)
# Out:
#                 sunrise               sunset        date
# 0   2020-12-01 07:16:37  2020-12-01 16:33:42  2020-12-01
# 1   2020-12-02 07:17:40  2020-12-02 16:33:27  2020-12-02
# 2   2020-12-03 07:18:42  2020-12-03 16:33:13  2020-12-03
# 3   2020-12-04 07:19:42  2020-12-04 16:33:03  2020-12-04
# 4   2020-12-05 07:20:41  2020-12-05 16:32:54  2020-12-05
# ..                  ...                  ...         ...
# 85  2021-02-24 06:49:09  2021-02-24 17:49:44  2021-02-24
# 86  2021-02-25 06:47:36  2021-02-25 17:50:59  2021-02-25
# 87  2021-02-26 06:46:01  2021-02-26 17:52:13  2021-02-26
# 88  2021-02-27 06:44:26  2021-02-27 17:53:27  2021-02-27
# 89  2021-02-28 06:42:50  2021-02-28 17:54:41  2021-02-28
#
# [90 rows x 3 columns]

# %%
# add sunrise and sunset times (winter2)

sun_times2['sunrise'] = sun_times2['sunrise'].dt.strftime('%Y-%m-%d %H:%M:%S')
sun_times2['sunset'] = sun_times2['sunset'].dt.strftime('%Y-%m-%d %H:%M:%S')

sun_times2['date'] = sun_times2['datetime']
sun_times2 = sun_times2.drop(columns=['datetime'])

print(sun_times2)
# Out:
#                 sunrise               sunset        date
# 0   2021-12-01 07:16:22  2021-12-01 16:33:46  2021-12-01
# 1   2021-12-02 07:17:25  2021-12-02 16:33:30  2021-12-02
# 2   2021-12-03 07:18:27  2021-12-03 16:33:16  2021-12-03
# 3   2021-12-04 07:19:28  2021-12-04 16:33:05  2021-12-04
# 4   2021-12-05 07:20:27  2021-12-05 16:32:56  2021-12-05
# ..                  ...                  ...         ...
# 85  2022-02-24 06:49:32  2022-02-24 17:49:26  2022-02-24
# 86  2022-02-25 06:47:58  2022-02-25 17:50:41  2022-02-25
# 87  2022-02-26 06:46:24  2022-02-26 17:51:55  2022-02-26
# 88  2022-02-27 06:44:49  2022-02-27 17:53:09  2022-02-27
# 89  2022-02-28 06:43:13  2022-02-28 17:54:23  2022-02-28
#
# [90 rows x 3 columns]

# %%
# add sunrise and sunset times (winter3)

sun_times3['sunrise'] = sun_times3['sunrise'].dt.strftime('%Y-%m-%d %H:%M:%S')
sun_times3['sunset'] = sun_times3['sunset'].dt.strftime('%Y-%m-%d %H:%M:%S')

sun_times3['date'] = sun_times3['datetime']
sun_times3 = sun_times3.drop(columns=['datetime'])

print(sun_times3)
# Out:
#                 sunrise               sunset        date
# 0   2022-12-01 07:16:06  2022-12-01 16:33:50  2022-12-01
# 1   2022-12-02 07:17:10  2022-12-02 16:33:33  2022-12-02
# 2   2022-12-03 07:18:12  2022-12-03 16:33:19  2022-12-03
# 3   2022-12-04 07:19:13  2022-12-04 16:33:07  2022-12-04
# 4   2022-12-05 07:20:13  2022-12-05 16:32:57  2022-12-05
# ..                  ...                  ...         ...
# 85  2023-02-24 06:49:54  2023-02-24 17:49:08  2023-02-24
# 86  2023-02-25 06:48:21  2023-02-25 17:50:23  2023-02-25
# 87  2023-02-26 06:46:47  2023-02-26 17:51:37  2023-02-26
# 88  2023-02-27 06:45:12  2023-02-27 17:52:51  2023-02-27
# 89  2023-02-28 06:43:37  2023-02-28 17:54:05  2023-02-28
#
# [90 rows x 3 columns]

# %%
# add 'date' column to all dataframes
precip_days1['date'] = precip_days1['datetime'].dt.date
precip_days2['date'] = precip_days2['datetime'].dt.date
precip_days3['date'] = precip_days3['datetime'].dt.date
# Out:
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772
# 4    2020-12-01 07:16:37  2020-12-01 16:33:42
# 5    2020-12-01 07:16:37  2020-12-01 16:33:42
# 6    2020-12-01 07:16:37  2020-12-01 16:33:42
# ..                   ...                  ...
# 685  2021-02-25 06:47:36  2021-02-25 17:50:59
# 686  2021-02-26 06:46:01  2021-02-26 17:52:13
# 687  2021-02-27 06:44:26  2021-02-27 17:53:27
# 688  2021-02-27 06:44:26  2021-02-27 17:53:27
# 689  2021-02-27 06:44:26  2021-02-27 17:53:27
#
# [314 rows x 7 columns]

# %%
# filter out transition hours
days1['sunrise'] = pd.to_datetime(days1['sunrise'])
days1['sunset'] = pd.to_datetime(days1['sunset'])

days1['sunrise+1'] = days1['sunrise'] + timedelta(hours = 1)
days1['sunset-1'] = days1['sunset'] - timedelta(hours = 1)

days1 = days1[days1['datetime'] <= days1['sunset-1']]
days1 = days1[days1['datetime'] >= days1['sunrise+1']]



days2['sunrise'] = pd.to_datetime(days2['sunrise'])
days2['sunset'] = pd.to_datetime(days2['sunset'])

days2['sunrise+1'] = days2['sunrise'] + timedelta(hours = 1)
days2['sunset-1'] = days2['sunset'] - timedelta(hours = 1)

days2 = days2[days2['datetime'] <= days2['sunset-1']]
days2 = days2[days2['datetime'] >= days2['sunrise+1']]



days3['sunrise'] = pd.to_datetime(days3['sunrise'])
days3['sunset'] = pd.to_datetime(days3['sunset'])

days3['sunrise+1'] = days3['sunrise'] + timedelta(hours = 1)
days3['sunset-1'] = days3['sunset'] - timedelta(hours = 1)

days3 = days3[days3['datetime'] <= days3['sunset-1']]
days3 = days3[days3['datetime'] >= days3['sunrise+1']]
# Out:
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\2882998222.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   days1['sunrise'] = pd.to_datetime(days1['sunrise'])
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\2882998222.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   days1['sunset'] = pd.to_datetime(days1['sunset'])
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\2882998222.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   days1['sunrise+1'] = days1['sunrise'] + timedelta(hours = 1)
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\2882998222.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   days1['sunset-1'] = days1['sunset'] - timedelta(hours = 1)
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\2882998222.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   days2['sunrise'] = pd.to_datetime(days2['sunrise'])
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\2882998222.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   days2['sunset'] = pd.to_datetime(days2['sunset'])
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\2882998222.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   days2['sunrise+1'] = days2['sunrise'] + timedelta(hours = 1)
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\2882998222.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   days2['sunset-1'] = days2['sunset'] - timedelta(hours = 1)
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\2882998222.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   days3['sunrise'] = pd.to_datetime(days3['sunrise'])
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\2882998222.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   days3['sunset'] = pd.to_datetime(days3['sunset'])
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\2882998222.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   days3['sunrise+1'] = days3['sunrise'] + timedelta(hours = 1)
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\2882998222.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   days3['sunset-1'] = days3['sunset'] - timedelta(hours = 1)

# %%
days1
# Out:
#     station            datetime  precip(mm) wxcodes        date  \
# 3       ITH 2020-12-01 09:56:00      0.0001  -RA BR  2020-12-01
# 4       ITH 2020-12-01 10:56:00      0.0001     -RA  2020-12-01
# 5       ITH 2020-12-01 11:56:00      0.0001  -RA BR  2020-12-01
# 6       ITH 2020-12-01 12:56:00      0.0001  -RA BR  2020-12-01
# 7       ITH 2020-12-01 13:56:00      0.0001     -RA  2020-12-01
# ..      ...                 ...         ...     ...         ...
# 684     ITH 2021-02-25 12:56:00      0.0001     -SN  2021-02-25
# 685     ITH 2021-02-25 14:56:00      0.0001     -SN  2021-02-25
# 686     ITH 2021-02-26 07:56:00      0.0001     -SN  2021-02-26
# 687     ITH 2021-02-27 07:56:00      0.0001     -SN  2021-02-27
# 688     ITH 2021-02-27 08:56:00      0.0001     -SN  2021-02-27
#
#                 sunrise              sunset           sunrise+1  \
# 3   2020-12-01 07:16:37 2020-12-01 16:33:42 2020-12-01 08:16:37
# 4   2020-12-01 07:16:37 2020-12-01 16:33:42 2020-12-01 08:16:37
# 5   2020-12-01 07:16:37 2020-12-01 16:33:42 2020-12-01 08:16:37
# 6   2020-12-01 07:16:37 2020-12-01 16:33:42 2020-12-01 08:16:37
# 7   2020-12-01 07:16:37 2020-12-01 16:33:42 2020-12-01 08:16:37
# ..                  ...                 ...                 ...
# 684 2021-02-25 06:47:36 2021-02-25 17:50:59 2021-02-25 07:47:36
# 685 2021-02-25 06:47:36 2021-02-25 17:50:59 2021-02-25 07:47:36
# 686 2021-02-26 06:46:01 2021-02-26 17:52:13 2021-02-26 07:46:01
# 687 2021-02-27 06:44:26 2021-02-27 17:53:27 2021-02-27 07:44:26
# 688 2021-02-27 06:44:26 2021-02-27 17:53:27 2021-02-27 07:44:26
#
#                sunset-1
# 3   2020-12-01 15:33:42
# 4   2020-12-01 15:33:42
# 5   2020-12-01 15:33:42
# 6   2020-12-01 15:33:42
# 7   2020-12-01 15:33:42
# ..                  ...
# 684 2021-02-25 16:50:59
# 685 2021-02-25 16:50:59
# 686 2021-02-26 16:52:13
# 687 2021-02-27 16:53:27
# 688 2021-02-27 16:53:27
#
# [257 rows x 9 columns]

# %%
# find total precip over each year
day_total1 = days1['precip(mm)'].sum()
day_total2 = days2['precip(mm)'].sum()
day_total3 = days3['precip(mm)'].sum()

# total number of obs each year
day_rows1 = days1.shape[0]
day_rows2 = days2.shape[0]
day_rows3 = days3.shape[0]

# %%
day_precip_per_hour1 = day_total1/ day_rows1
day_precip_per_hour2 = day_total2/ day_rows2
day_precip_per_hour3 = day_total3/ day_rows3

# %%
print('2020-2021:', day_precip_per_hour1)
print('2021-2022:', day_precip_per_hour2)
print('2022-2023:', day_precip_per_hour3)
# Out:
# 2020-2021: 0.027519844357976653
# 2021-2022: 0.10013560975609756
# 2022-2023: 0.21091105263157892

# %%
# filter out only times after sunset & before NEXT sunrise 

nights1 = merged1[(merged1['datetime'] < merged1['sunrise']) | (merged1['datetime'] > merged1['sunset'])]
nights2 = merged2[(merged2['datetime'] < merged2['sunrise']) | (merged2['datetime'] > merged2['sunset'])]
nights3 = merged3[(merged3['datetime'] < merged3['sunrise']) | (merged3['datetime'] > merged3['sunset'])]

nights1
# Out:
#     station            datetime  precip(mm) wxcodes        date  \
# 0       ITH 2020-12-01 02:56:00      0.0001  -RA BR  2020-12-01
# 1       ITH 2020-12-01 03:56:00      0.0001  -RA BR  2020-12-01
# 10      ITH 2020-12-01 16:56:00      0.0001     -RA  2020-12-01
# 11      ITH 2020-12-01 17:56:00      0.0001     -RA  2020-12-01
# 12      ITH 2020-12-01 18:56:00      0.0001     -RA  2020-12-01
# ..      ...                 ...         ...     ...         ...
# 679     ITH 2021-02-23 18:56:00      0.2500     -SN  2021-02-23
# 680     ITH 2021-02-23 19:56:00      0.0001     -RA  2021-02-23
# 681     ITH 2021-02-23 20:56:00      0.0001     -SN  2021-02-23
# 682     ITH 2021-02-23 21:56:00      0.0001     -SN  2021-02-23
# 683     ITH 2021-02-24 20:56:00      0.0001     -RA  2021-02-24
#
#                  sunrise               sunset
# 0    2020-12-01 07:16:37  2020-12-01 16:33:42
# 1    2020-12-01 07:16:37  2020-12-01 16:33:42
# 10   2020-12-01 07:16:37  2020-12-01 16:33:42
# 11   2020-12-01 07:16:37  2020-12-01 16:33:42
# 12   2020-12-01 07:16:37  2020-12-01 16:33:42
# ..                   ...                  ...
# 679  2021-02-23 06:50:42  2021-02-23 17:48:30
# 680  2021-02-23 06:50:42  2021-02-23 17:48:30
# 681  2021-02-23 06:50:42  2021-02-23 17:48:30
# 682  2021-02-23 06:50:42  2021-02-23 17:48:30
# 683  2021-02-24 06:49:09  2021-02-24 17:49:44
#
# [376 rows x 7 columns]

# %%
# filter out transition hours
nights1['sunrise'] = pd.to_datetime(nights1['sunrise'])
nights1['sunset'] = pd.to_datetime(nights1['sunset'])

nights1['sunrise-1'] = nights1['sunrise'] - timedelta(hours = 1) + timedelta(days = 1)
nights1['sunset+1'] = nights1['sunset'] + timedelta(hours = 1)

nights1 = nights1[nights1['datetime'] >= nights1['sunset+1']]
nights1 = nights1[nights1['datetime'] <= nights1['sunrise-1']]



nights2['sunrise'] = pd.to_datetime(nights2['sunrise'])
nights2['sunset'] = pd.to_datetime(nights2['sunset'])

nights2['sunrise-1'] = nights2['sunrise'] - timedelta(hours = 1) + timedelta(days = 1)
nights2['sunset+1'] = nights2['sunset'] + timedelta(hours = 1)

nights2 = nights2[nights2['datetime'] >= nights2['sunset+1']]
nights2 = nights2[nights2['datetime'] <= nights2['sunrise-1']]



nights3['sunrise'] = pd.to_datetime(nights3['sunrise'])
nights3['sunset'] = pd.to_datetime(nights3['sunset'])

nights3['sunrise-1'] = nights3['sunrise'] - timedelta(hours = 1) + timedelta(days = 1)
nights3['sunset+1'] = nights3['sunset'] + timedelta(hours = 1)

nights3 = nights3[nights3['datetime'] >= nights3['sunset+1']]
nights3 = nights3[nights3['datetime'] <= nights3['sunrise-1']]
# Out:
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\36922422.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nights1['sunrise'] = pd.to_datetime(nights1['sunrise'])
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\36922422.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nights1['sunset'] = pd.to_datetime(nights1['sunset'])
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\36922422.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nights1['sunrise-1'] = nights1['sunrise'] - timedelta(hours = 1) + timedelta(days = 1)
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\36922422.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nights1['sunset+1'] = nights1['sunset'] + timedelta(hours = 1)
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\36922422.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nights2['sunrise'] = pd.to_datetime(nights2['sunrise'])
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\36922422.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nights2['sunset'] = pd.to_datetime(nights2['sunset'])
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\36922422.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nights2['sunrise-1'] = nights2['sunrise'] - timedelta(hours = 1) + timedelta(days = 1)
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\36922422.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nights2['sunset+1'] = nights2['sunset'] + timedelta(hours = 1)
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\36922422.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nights3['sunrise'] = pd.to_datetime(nights3['sunrise'])
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\36922422.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nights3['sunset'] = pd.to_datetime(nights3['sunset'])
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\36922422.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nights3['sunrise-1'] = nights3['sunrise'] - timedelta(hours = 1) + timedelta(days = 1)
# C:\Users\alyha\AppData\Local\Temp\ipykernel_12772\36922422.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nights3['sunset+1'] = nights3['sunset'] + timedelta(hours = 1)

# %%
# find total precip over each year
night_total1 = nights1['precip(mm)'].sum()
night_total2 = nights2['precip(mm)'].sum()
night_total3 = nights3['precip(mm)'].sum()

# total number of obs each year
night_rows1 = nights1.shape[0]
night_rows2 = nights2.shape[0]
night_rows3 = nights3.shape[0]

# %%
night_precip_per_hour1 = night_total1/ night_rows1
night_precip_per_hour2 = night_total2/ night_rows2
night_precip_per_hour3 = night_total3/ night_rows3

# %%
print('2020-2021:', night_precip_per_hour1)
print('2021-2022:', night_precip_per_hour2)
print('2022-2023:', night_precip_per_hour3)
# Out:
# 2020-2021: 0.0075303571428571425
# 2021-2022: 0.11717777777777781
# 2022-2023: 0.21874655172413798

# %%
data = pd.concat([days1, nights1, days2, nights2, days3, nights3])

data['date'] = pd.to_datetime(data['date'])
data['month'] = data['date'].dt.month

data['state'] = 'NY'

data.to_csv('ith.csv', index=False)
